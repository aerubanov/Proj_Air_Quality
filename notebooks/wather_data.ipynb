# %%
import pandas as pd

# %%
data = pd.read_csv('../DATA/wather_centr_2019-04-01_2019-12-08.csv',delimiter=';',
                   skiprows=6, parse_dates=['Местное время в Москве (центр, Балчуг)'], index_col=False)
data = data.rename(columns={'Местное время в Москве (центр, Балчуг)': 'date'})

# %%
data = data.set_index('date')
data = data[::-1]

# %%
data
# Out:
#                        T     Po      P  Pa   U  \
# date
# 2019-01-04 00:00:00  9.0  743.7  754.9 NaN  67
# 2019-01-04 03:00:00  6.7  744.6  755.9 NaN  59
# 2019-01-04 06:00:00  4.9  746.1  757.6 NaN  61
# 2019-01-04 09:00:00  4.5  748.0  759.5 NaN  61
# 2019-01-04 12:00:00  4.5  750.1  761.6 NaN  54
# ...                  ...    ...    ...  ..  ..
# 2019-08-12 09:00:00  1.4  739.6  751.0 NaN  80
# 2019-08-12 12:00:00  2.1  740.0  751.5 NaN  81
# 2019-08-12 15:00:00  3.3  740.2  751.6 NaN  76
# 2019-08-12 18:00:00  3.5  742.0  753.4 NaN  77
# 2019-08-12 21:00:00  2.7  743.4  754.9 NaN  83
#
#                                                        DD  Ff  ff10  ff3  \
# date
# 2019-01-04 00:00:00                Ветер, дующий с запада   2   NaN  NaN
# 2019-01-04 03:00:00                Ветер, дующий с запада   2   NaN  NaN
# 2019-01-04 06:00:00                Ветер, дующий с запада   2   NaN  NaN
# 2019-01-04 09:00:00  Ветер, дующий с западо-северо-запада   2   NaN  NaN
# 2019-01-04 12:00:00     Ветер, дующий с западо-юго-запада   3   NaN  NaN
# ...                                                   ...  ..   ...  ...
# 2019-08-12 09:00:00     Ветер, дующий с западо-юго-запада   1   NaN  NaN
# 2019-08-12 12:00:00  Ветер, дующий с западо-северо-запада   1   NaN  NaN
# 2019-08-12 15:00:00            Ветер, дующий с юго-запада   1   NaN  NaN
# 2019-08-12 18:00:00                Ветер, дующий с запада   1   NaN  NaN
# 2019-08-12 21:00:00                Ветер, дующий с запада   1   NaN  NaN
#
#                                              N  ...  \
# date                                            ...
# 2019-01-04 00:00:00                      100%.  ...
# 2019-01-04 03:00:00  90  или более, но не 100%  ...
# 2019-01-04 06:00:00               Облаков нет.  ...
# 2019-01-04 09:00:00                  70 – 80%.  ...
# 2019-01-04 12:00:00                      100%.  ...
# ...                                        ...  ...
# 2019-08-12 09:00:00                      100%.  ...
# 2019-08-12 12:00:00                      100%.  ...
# 2019-08-12 15:00:00                      100%.  ...
# 2019-08-12 18:00:00                      100%.  ...
# 2019-08-12 21:00:00  90  или более, но не 100%  ...
#
#                                                                     Cm  \
# date
# 2019-01-04 00:00:00                                                NaN
# 2019-01-04 03:00:00  Высококучевые просвечивающие, расположенные на...
# 2019-01-04 06:00:00                                                NaN
# 2019-01-04 09:00:00  Высококучевых, высокослоистых или слоисто-дожд...
# 2019-01-04 12:00:00                                                NaN
# ...                                                                ...
# 2019-08-12 09:00:00                                                NaN
# 2019-08-12 12:00:00                                                NaN
# 2019-08-12 15:00:00                                                NaN
# 2019-08-12 18:00:00                                                NaN
# 2019-08-12 21:00:00  Высококучевые просвечивающие, полосами, либо о...
#
#                                                                     Ch    VV  \
# date
# 2019-01-04 00:00:00                                                NaN  10.0
# 2019-01-04 03:00:00  Перистых, перисто-кучевых или перисто-слоистых...  10.0
# 2019-01-04 06:00:00                                                NaN  10.0
# 2019-01-04 09:00:00  Перистых, перисто-кучевых или перисто-слоистых...  10.0
# 2019-01-04 12:00:00                                                NaN  10.0
# ...                                                                ...   ...
# 2019-08-12 09:00:00                                                NaN  10.0
# 2019-08-12 12:00:00                                                NaN  10.0
# 2019-08-12 15:00:00                                                NaN  10.0
# 2019-08-12 18:00:00                                                NaN  10.0
# 2019-08-12 21:00:00  Перистых, перисто-кучевых или перисто-слоистых...  10.0
#
#                       Td            RRR    tR  \
# date
# 2019-01-04 00:00:00  3.2            NaN   NaN
# 2019-01-04 03:00:00 -0.9            NaN   NaN
# 2019-01-04 06:00:00 -2.1  Следы осадков  12.0
# 2019-01-04 09:00:00 -2.4  Следы осадков  12.0
# 2019-01-04 12:00:00 -4.1            NaN   NaN
# ...                  ...            ...   ...
# 2019-08-12 09:00:00 -1.8    Осадков нет  12.0
# 2019-08-12 12:00:00 -0.8            NaN   NaN
# 2019-08-12 15:00:00 -0.5            NaN   NaN
# 2019-08-12 18:00:00 -0.2    Осадков нет  12.0
# 2019-08-12 21:00:00  0.0    Осадков нет  12.0
#
#                                                                      E   Tg  \
# date
# 2019-01-04 00:00:00                                                NaN  NaN
# 2019-01-04 03:00:00                                                NaN  NaN
# 2019-01-04 06:00:00                                                NaN  NaN
# 2019-01-04 09:00:00  Поверхность почвы сырая (вода застаивается на ...  1.0
# 2019-01-04 12:00:00                                                NaN  NaN
# ...                                                                ...  ...
# 2019-08-12 09:00:00                                                NaN  NaN
# 2019-08-12 12:00:00                                                NaN  NaN
# 2019-08-12 15:00:00                                                NaN  NaN
# 2019-08-12 18:00:00                                                NaN  NaN
# 2019-08-12 21:00:00                                                NaN  NaN
#
#                       E'  sss
# date
# 2019-01-04 00:00:00  NaN  NaN
# 2019-01-04 03:00:00  NaN  NaN
# 2019-01-04 06:00:00  NaN  NaN
# 2019-01-04 09:00:00  NaN  NaN
# 2019-01-04 12:00:00  NaN  NaN
# ...                  ...  ...
# 2019-08-12 09:00:00  NaN  NaN
# 2019-08-12 12:00:00  NaN  NaN
# 2019-08-12 15:00:00  NaN  NaN
# 2019-08-12 18:00:00  NaN  NaN
# 2019-08-12 21:00:00  NaN  NaN
#
# [2015 rows x 28 columns]

# %%
sel_data = pd.DataFrame(index=data.index)

# %%
sel_data['temp_meteo'] = data['T']
sel_data['pres_meteo'] = data.Po *133.322 # transfor in Pa
sel_data['hum_meteo'] = data.U
sel_data['wind_direction'] = data.DD
sel_data['wind_speed'] = data.Ff
sel_data['precipitation'] = data.W1
sel_data['prec_amount'] = data.RRR
sel_data['visibility'] = data.VV
sel_data['dew_point_temp'] = data.Td

# %%
sel_data.head()
# Out:
#                      temp_meteo   pres_meteo  hum_meteo  \
# date
# 2019-01-04 00:00:00         9.0   99151.5714         67
# 2019-01-04 03:00:00         6.7   99271.5612         59
# 2019-01-04 06:00:00         4.9   99471.5442         61
# 2019-01-04 09:00:00         4.5   99724.8560         61
# 2019-01-04 12:00:00         4.5  100004.8322         54
#
#                                            wind_direction  wind_speed  \
# date
# 2019-01-04 00:00:00                Ветер, дующий с запада           2
# 2019-01-04 03:00:00                Ветер, дующий с запада           2
# 2019-01-04 06:00:00                Ветер, дующий с запада           2
# 2019-01-04 09:00:00  Ветер, дующий с западо-северо-запада           2
# 2019-01-04 12:00:00     Ветер, дующий с западо-юго-запада           3
#
#                         pecipitation  visibility  dew_point_temp  \
# date
# 2019-01-04 00:00:00  Ливень (ливни).        10.0             3.2
# 2019-01-04 03:00:00  Ливень (ливни).        10.0            -0.9
# 2019-01-04 06:00:00              NaN        10.0            -2.1
# 2019-01-04 09:00:00              NaN        10.0            -2.4
# 2019-01-04 12:00:00              NaN        10.0            -4.1
#
#                        precipitation    prec_amount
# date
# 2019-01-04 00:00:00  Ливень (ливни).            NaN
# 2019-01-04 03:00:00  Ливень (ливни).            NaN
# 2019-01-04 06:00:00              NaN  Следы осадков
# 2019-01-04 09:00:00              NaN  Следы осадков
# 2019-01-04 12:00:00              NaN            NaN

# %%
sel_data = sel_data.resample('5T').pad()

# %%
sel_data
# Out:
#                      temp_meteo   pres_meteo  hum_meteo  \
# date
# 2019-01-04 00:00:00         9.0   99151.5714         67
# 2019-01-04 00:05:00         9.0   99151.5714         67
# 2019-01-04 00:10:00         9.0   99151.5714         67
# 2019-01-04 00:15:00         9.0   99151.5714         67
# 2019-01-04 00:20:00         9.0   99151.5714         67
# ...                         ...          ...        ...
# 2019-12-11 20:40:00         4.1  101098.0726         72
# 2019-12-11 20:45:00         4.1  101098.0726         72
# 2019-12-11 20:50:00         4.1  101098.0726         72
# 2019-12-11 20:55:00         4.1  101098.0726         72
# 2019-12-11 21:00:00         4.2  101204.7302         71
#
#                                            wind_direction  wind_speed  \
# date
# 2019-01-04 00:00:00                Ветер, дующий с запада           2
# 2019-01-04 00:05:00                Ветер, дующий с запада           2
# 2019-01-04 00:10:00                Ветер, дующий с запада           2
# 2019-01-04 00:15:00                Ветер, дующий с запада           2
# 2019-01-04 00:20:00                Ветер, дующий с запада           2
# ...                                                   ...         ...
# 2019-12-11 20:40:00  Ветер, дующий с западо-северо-запада           3
# 2019-12-11 20:45:00  Ветер, дующий с западо-северо-запада           3
# 2019-12-11 20:50:00  Ветер, дующий с западо-северо-запада           3
# 2019-12-11 20:55:00  Ветер, дующий с западо-северо-запада           3
# 2019-12-11 21:00:00                Ветер, дующий с запада           1
#
#                         pecipitation  visibility  dew_point_temp  \
# date
# 2019-01-04 00:00:00  Ливень (ливни).        10.0             3.2
# 2019-01-04 00:05:00  Ливень (ливни).        10.0             3.2
# 2019-01-04 00:10:00  Ливень (ливни).        10.0             3.2
# 2019-01-04 00:15:00  Ливень (ливни).        10.0             3.2
# 2019-01-04 00:20:00  Ливень (ливни).        10.0             3.2
# ...                              ...         ...             ...
# 2019-12-11 20:40:00              NaN        10.0            -0.5
# 2019-12-11 20:45:00              NaN        10.0            -0.5
# 2019-12-11 20:50:00              NaN        10.0            -0.5
# 2019-12-11 20:55:00              NaN        10.0            -0.5
# 2019-12-11 21:00:00              NaN        10.0            -0.6
#
#                        precipitation  prec_amount
# date
# 2019-01-04 00:00:00  Ливень (ливни).          NaN
# 2019-01-04 00:05:00  Ливень (ливни).          NaN
# 2019-01-04 00:10:00  Ливень (ливни).          NaN
# 2019-01-04 00:15:00  Ливень (ливни).          NaN
# 2019-01-04 00:20:00  Ливень (ливни).          NaN
# ...                              ...          ...
# 2019-12-11 20:40:00              NaN          0.1
# 2019-12-11 20:45:00              NaN          0.1
# 2019-12-11 20:50:00              NaN          0.1
# 2019-12-11 20:55:00              NaN          0.1
# 2019-12-11 21:00:00              NaN  Осадков нет
#
# [98461 rows x 10 columns]
