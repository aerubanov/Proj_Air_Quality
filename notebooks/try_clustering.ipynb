# %%
import pandas as pd
import matplotlib as plt
import datetime
import typing

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_csv('../DATA/processed/dataset.csv', parse_dates=['date'])
data = data.set_index('date')

# %%
last_week = data[str(datetime.date.today()-datetime.timedelta(days=8)):str(datetime.date.today()-datetime.timedelta(days=1))]

# %%
last_week
# Out:
#                            P1        P2      pressure  temperature   humidity  \
# date
# 2020-01-21 00:00:00  4.182316  1.394412  98127.812197     3.093843  65.963967
# 2020-01-21 00:05:00  3.981080  1.391687  98119.233927     3.098511  65.946084
# 2020-01-21 00:10:00  4.172742  1.424872  98143.762100     3.078051  66.324587
# 2020-01-21 00:15:00  3.748293  1.359150  98146.191509     3.035184  66.477143
# 2020-01-21 00:20:00  4.026442  1.394609  98133.060511     3.059691  66.552611
# ...                       ...       ...           ...          ...        ...
# 2020-01-27 23:40:00  6.795175  3.078020  97894.093421    -2.899447  64.661410
# 2020-01-27 23:45:00  6.720736  3.038285  97892.057291    -2.922773  64.920405
# 2020-01-27 23:50:00  6.943441  3.099808  97878.348927    -2.966495  65.157490
# 2020-01-27 23:55:00  6.808811  3.136675  97886.648802    -2.978950  65.180133
# 2020-01-28 00:00:00  6.774525  3.173259  97881.866419    -3.013038  65.418615
#
#                      temp_meteo   pres_meteo  hum_meteo  \
# date
# 2020-01-21 00:00:00         2.3  100484.7914       81.0
# 2020-01-21 00:05:00         2.3  100484.7914       81.0
# 2020-01-21 00:10:00         2.3  100484.7914       81.0
# 2020-01-21 00:15:00         2.3  100484.7914       81.0
# 2020-01-21 00:20:00         2.3  100484.7914       81.0
# ...                         ...          ...        ...
# 2020-01-27 23:40:00        -2.4  100124.8220       49.0
# 2020-01-27 23:45:00        -2.4  100124.8220       49.0
# 2020-01-27 23:50:00        -2.4  100124.8220       49.0
# 2020-01-27 23:55:00        -2.4  100124.8220       49.0
# 2020-01-28 00:00:00        -3.3  100124.8220       57.0
#
#                                           wind_direction  wind_speed  \
# date
# 2020-01-21 00:00:00               Ветер, дующий с запада         2.0
# 2020-01-21 00:05:00               Ветер, дующий с запада         2.0
# 2020-01-21 00:10:00               Ветер, дующий с запада         2.0
# 2020-01-21 00:15:00               Ветер, дующий с запада         2.0
# 2020-01-21 00:20:00               Ветер, дующий с запада         2.0
# ...                                                  ...         ...
# 2020-01-27 23:40:00  Ветер, дующий с востоко-юго-востока         2.0
# 2020-01-27 23:45:00  Ветер, дующий с востоко-юго-востока         2.0
# 2020-01-27 23:50:00  Ветер, дующий с востоко-юго-востока         2.0
# 2020-01-27 23:55:00  Ветер, дующий с востоко-юго-востока         2.0
# 2020-01-28 00:00:00              Ветер, дующий с востока         1.0
#
#                     precipitation  prec_amount  visibility  dew_point_temp
# date
# 2020-01-21 00:00:00           NaN          NaN        10.0            -0.7
# 2020-01-21 00:05:00           NaN          NaN        10.0            -0.7
# 2020-01-21 00:10:00           NaN          NaN        10.0            -0.7
# 2020-01-21 00:15:00           NaN          NaN        10.0            -0.7
# 2020-01-21 00:20:00           NaN          NaN        10.0            -0.7
# ...                           ...          ...         ...             ...
# 2020-01-27 23:40:00           NaN  Осадков нет        10.0           -11.7
# 2020-01-27 23:45:00           NaN  Осадков нет        10.0           -11.7
# 2020-01-27 23:50:00           NaN  Осадков нет        10.0           -11.7
# 2020-01-27 23:55:00           NaN  Осадков нет        10.0           -11.7
# 2020-01-28 00:00:00           NaN          NaN        10.0           -10.8
#
# [2017 rows x 14 columns]
